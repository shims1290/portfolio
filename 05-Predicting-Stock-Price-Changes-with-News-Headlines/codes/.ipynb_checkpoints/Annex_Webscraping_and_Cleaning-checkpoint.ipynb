# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Capstone Project: Predicting Stock Price Changes based on News

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import datetime
import requests
import re
import time
import numpy as np
from bs4 import BeautifulSoup

pd.set_option('display.max.columns', None)
pd.set_option('display.max.colwidth', 100)

# %% [markdown]
# ### Basic Data Cleaning and Aggregation by Unique Dates

# %%
# import scraped data & retain only news text
pfizer = pd.read_csv("../assets/scraped_news.csv")
pfizer.drop(columns=['links'], inplace=True)

# %%
pfizer.head()
# Out:
#         dates                                           headlines  \
# 0   2012-1-13   Nestle declines comment on Pfizer unit bid report
# 1   2012-1-27  US FDA approves Pfizer\'s Inlyta for kidney cancer
# 2   2012-1-31         Generics take toll on Pfizer, Lilly profits
# 3   2012-1-31      Pfizer trims 2012 view, citing stronger dollar
# 4  2012-10-04  Trial suggests Prevnar may also protect ages 18-49
#
#                                                                                        article_content
# 0   ZURICH, Jan 13 (Reuters) - Nestle, the world’s biggest food group, declined to comment on a rep...
# 1   WASHINGTON (Reuters) - Pfizer’s Inlyta drug for patients with advanced kidney cancer won approv...
# 2   (Reuters) - Competition from low-cost generic drugs squeezed quarterly profits at Pfizer Inc PF...
# 3   (Reuters) - Pfizer Inc PFE.N reported sharply lower quarterly earnings, hurt by generic forms o...
# 4   (Reuters) - Pfizer Inc said a late-stage trial of its vaccine to protect against pneumococcal b...

# %%
# create function to remove Country, Date and (Reuters) tags 
def remove_artcicle_tags(text):
    for t in text:
        t = re.findall(r'^.*\(\w+\) - (.*)', text)
    return t

# %%
# apply above function and print new df.head()
pfizer['article_content'] = pfizer['article_content'].apply(remove_artcicle_tags)
print(pfizer.head())
# Out:
#         dates                                           headlines  \
# 0   2012-1-13   Nestle declines comment on Pfizer unit bid report
# 1   2012-1-27  US FDA approves Pfizer\'s Inlyta for kidney cancer
# 2   2012-1-31         Generics take toll on Pfizer, Lilly profits
# 3   2012-1-31      Pfizer trims 2012 view, citing stronger dollar
# 4  2012-10-04  Trial suggests Prevnar may also protect ages 18-49
#
#                                                                                        article_content
# 0  [Nestle, the world’s biggest food group, declined to comment on a report it had placed a bid to ...
# 1  [Pfizer’s Inlyta drug for patients with advanced kidney cancer won approval from U.S. regulators...
# 2  [Competition from low-cost generic drugs squeezed quarterly profits at Pfizer Inc PFE.N and Eli ...
# 3  [Pfizer Inc PFE.N reported sharply lower quarterly earnings, hurt by generic forms of its Lipito...
# 4  [Pfizer Inc said a late-stage trial of its vaccine to protect against pneumococcal bacteria sugg...

# %%
# create new column to concatenate all text info
pfizer['news_text'] = pfizer['headlines'] + " " + pfizer['article_content'].astype(str)

# %%
# print sample to check that the concantenation worked 
pfizer['news_text'][0]
# Out:
# "Nestle declines comment on Pfizer unit bid report ['Nestle, the world’s biggest food group, declined to comment on a report it had placed a bid to buy Pfizer Inc’s baby formula business.“We never comment on market rumours,” a spokeswoman for the firm said.Bloomberg, citing people familiar with knowledge of the matter, reported that Nestle as well as France’s Danone SA had put in an offer to buy the unit.']"

# %%
# create a function to check if company is mentioned in the news report at all
def company_in_text(text, company):
    if company in text.lower():
        return 1
    else:
        return 0

# %%
# apply function to create feature column
pfizer['mentioned'] = pfizer['news_text'].apply(lambda x: company_in_text(x, "pfizer"))

# %%
# show sample articles where the company was not mentioned at all
pfizer[pfizer['mentioned']==0].tail()
# Out:
#           dates  \
# 6024  2021-8-25
# 6036  2021-8-26
# 6043  2021-8-27
# 6071  2021-8-30
# 6094  2021-8-31
#
#                                                                                headlines  \
# 6024                                          Delta Air Lines wields Covid vaccine stick
# 6036     Fact Check-Video does not prove COVID-19 vaccines cause blood anomalies\xc2\xa0
# 6043  Fact Check-Meme comparing products it says were approved by FDA is missing context
# 6071                           Fact Check-Cigarettes are FDA regulated, not FDA approved
# 6094            COVID-19 cases rise in Australia\'s Victoria as lockdown extension looms
#
#                                                                                           article_content  \
# 6024                                                                                                   []
# 6036                                                                                                   []
# 6043                                                                                                   []
# 6071                                                                                                   []
# 6094  [Australian authorities on Wednesday extended the COVID-19 lockdown in Melbourne for another thr...
#
#                                                                                                 news_text  \
# 6024                                                        Delta Air Lines wields Covid vaccine stick []
# 6036                   Fact Check-Video does not prove COVID-19 vaccines cause blood anomalies\xc2\xa0 []
# 6043                Fact Check-Meme comparing products it says were approved by FDA is missing context []
# 6071                                         Fact Check-Cigarettes are FDA regulated, not FDA approved []
# 6094  COVID-19 cases rise in Australia\'s Victoria as lockdown extension looms ['Australian authoritie...
#
#       mentioned
# 6024          0
# 6036          0
# 6043          0
# 6071          0
# 6094          0

# %%
# print an example of the text
print(pfizer['news_text'][6094])
# Out:
# COVID-19 cases rise in Australia\'s Victoria as lockdown extension looms ['Australian authorities on Wednesday extended the COVID-19 lockdown in Melbourne for another three weeks, as they shift their focus to rapid vaccination drives and move away from a suppression strategy to bring cases down to zero.Victorian Premier Daniel Andrews flagged a staggered easing of the tough restrictions once 70% of the state\'s adult residents receive at least one dose, a milestone he hopes to reach at least by Sept. 23, based on current vaccination rates."We have thrown everything at this, but it is now clear to us that we are not going to drive these numbers down, they are instead going to increase," Andrews told reporters in Melbourne, the state capital, after a lockdown for nearly a month failed to quell the outbreak. The lockdown was due to end on Thursday."We got to buy time to allow vaccinations to be undertaken all the while doing this very hard work, this very painful and difficult work, to keep a lid as much as we can on cases."New local cases jumped to 120 in Victoria from 76 a day earlier. Of the new cases, 100 have spent time in the community while infectious.Neighbouring New South Wales state, home to Sydney, on Wednesday brought forward its target date to fully vaccinate 70% of people above 16 to the middle of next month from the initial target of the end of October, as outbreaks spurred a surge in inoculation."No matter where you live, life will be much, much better, much freer, as long as you\'re vaccinated at 70%," Berejiklian told reporters. So far 37% are fully vaccinated in the state, while 67% have had at least one dose, slightly higher than the national numbers but well below most comparable nations.A total of 1,116 new cases were detected in New South Wales, down from 1,164 a day earlier. NSW reported four new deaths, taking the total number of deaths in the latest outbreak to 100.Prime Minister Scott Morrison told parliament on Wednesday Australians ultimately needed to be released from lockdowns."Australia can live with this virus," he said in Canberra.LIVING WITH COVIDAustralia is trying to get a handle on the third wave of infections that has locked down more than half of its 25 million population. Sydney and Melbourne, its largest cities, and capital Canberra are in weeks-long strict stay-at-home orders.Despite the recent flare-ups, it has managed to keep its coronavirus numbers relatively low, with just over 55,000 cases and 1,012 deaths.Among the Group of 20 big economies, Australia was the last to record 1,000 COVID-19 deaths, a grim but modest marker by global standards reached this week.  read more Several major Asia-Pacific economies have fewer COVID-19 deaths, with New Zealand recording just 26.  read more While Australian authorities had been able to douse past outbreaks through lockdowns, the highly infectious Delta variant has forced the country\'s two biggest states to plan for a reopening even as infections rise.Australian Medical Association vice president Chris Moy told Reuters that Delta\'s high infectivity, short incubation and asymptomatic spread had meant the "old playbook did not work"."Your window of opportunity at the start to eliminate it is so much smaller and basically once you\'re passed that, Delta decides its destiny," Moy said.The federal government is pressing the states and territories to stick to a national reopening plan once vaccination rates reach 70%-80% although some virus-free states said they may delay given the rapidly rising Sydney cases.  read more Federal Treasurer Josh Frydenberg urged the state leaders to follow the national reopening plans."Stick to the plan ... a plan that allows businesses to reopen and plan for their own future ... a plan that takes Australia forward to living safely with the virus," Frydenberg said.Our Standards: The Thomson Reuters Trust Principles.']

# %%
# we remove articles with no mention of the company in our dataset
pfizer = pfizer[pfizer['mentioned']==1]

# %%
pfizer.head()
# Out:
#         dates                                           headlines  \
# 0   2012-1-13   Nestle declines comment on Pfizer unit bid report
# 1   2012-1-27  US FDA approves Pfizer\'s Inlyta for kidney cancer
# 2   2012-1-31         Generics take toll on Pfizer, Lilly profits
# 3   2012-1-31      Pfizer trims 2012 view, citing stronger dollar
# 4  2012-10-04  Trial suggests Prevnar may also protect ages 18-49
#
#                                                                                        article_content  \
# 0  [Nestle, the world’s biggest food group, declined to comment on a report it had placed a bid to ...
# 1  [Pfizer’s Inlyta drug for patients with advanced kidney cancer won approval from U.S. regulators...
# 2  [Competition from low-cost generic drugs squeezed quarterly profits at Pfizer Inc PFE.N and Eli ...
# 3  [Pfizer Inc PFE.N reported sharply lower quarterly earnings, hurt by generic forms of its Lipito...
# 4  [Pfizer Inc said a late-stage trial of its vaccine to protect against pneumococcal bacteria sugg...
#
#                                                                                              news_text  \
# 0  Nestle declines comment on Pfizer unit bid report ['Nestle, the world’s biggest food group, decl...
# 1  US FDA approves Pfizer\'s Inlyta for kidney cancer ['Pfizer’s Inlyta drug for patients with adva...
# 2  Generics take toll on Pfizer, Lilly profits ['Competition from low-cost generic drugs squeezed q...
# 3  Pfizer trims 2012 view, citing stronger dollar ['Pfizer Inc PFE.N reported sharply lower quarter...
# 4  Trial suggests Prevnar may also protect ages 18-49 ['Pfizer Inc said a late-stage trial of its v...
#
#    mentioned
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
# count number of news each day
news_volume = pfizer.groupby('dates').size()
news_volume.head()
# Out:
# dates
# 2012-1-13     1
# 2012-1-27     1
# 2012-1-31     2
# 2012-10-04    2
# 2012-10-05    1
# dtype: int64

# %%
# group headlines together such that each day will only be recorded as one observation
agg_text = pfizer.groupby('dates')['news_text'].apply(list)
agg_df = pd.DataFrame({'text':agg_text, 'news_count':news_volume})
    
# set the date index in a particular format 
agg_df.index = pd.to_datetime(agg_df.index,format="%Y-%m-%d")

# %%
agg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1079 entries, 2012-01-13 to 2021-09-01
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   text        1079 non-null   object
#  1   news_count  1079 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 25.3+ KB

# %%
agg_df.head()
# Out:
#                                                                                                            text  \
# dates
# 2012-01-13  [Nestle declines comment on Pfizer unit bid report ['Nestle, the world’s biggest food group, dec...
# 2012-01-27  [US FDA approves Pfizer\'s Inlyta for kidney cancer ['Pfizer’s Inlyta drug for patients with adv...
# 2012-01-31  [Generics take toll on Pfizer, Lilly profits ['Competition from low-cost generic drugs squeezed ...
# 2012-10-04  [Trial suggests Prevnar may also protect ages 18-49 ['Pfizer Inc said a late-stage trial of its ...
# 2012-10-05  [Pfizer to appeal India decision to revoke cancer drug patent ['Pfizer Ltd, the India unit of U....
#
#             news_count
# dates
# 2012-01-13           1
# 2012-01-27           1
# 2012-01-31           2
# 2012-10-04           2
# 2012-10-05           1

# %% [markdown]
# ### Webscraping for stocks data using the Alpha Vantage API

# %%
def scrape_stocks(ticker):
    
    # pull API request
    url = ('https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=' + ticker + 
           '&outputsize=full&apikey=4ALQKUAMC2QCOZW9')
    r = requests.get(url)
    data = r.json()
    
    # save data in panda dataframe
    df = pd.DataFrame(data["Time Series (Daily)"])
    df = df.T
    
    # grab only stocks data between 01 Jan 2011 and 31 August 2021
    df = df.loc['2021-08-31':'2012-01-10']
    
    # keep only relevant data columns (i.e. adjusted close price and volume)
    df = df.iloc[:, 4:6]
    
    # rename column names 
    df.rename(columns={"5. adjusted close": "close_price",
                       "6. volume": "volume" }, inplace=True)
    
    # change datatype from string to float
    for column in df.columns:
        df[column] = pd.to_numeric(df[column])
        
    # set the date index in standard format 
    df.index = pd.to_datetime(df.index,format="%Y-%m-%d")
    df.sort_index(inplace=True)
    df['date'] = pd.to_datetime(df.index,format="%Y-%m-%d")
    
    # create feature columns
    df['pct_px_change'] = (df['close_price'].pct_change()) * 100
    df['abs_pct_change'] = abs((df['close_price'].pct_change()) * 100)
        
    return df

# %%
# scrape relevant stocks data
pfe = scrape_stocks('pfe')
sp500 = scrape_stocks('spy')
sp500.drop(columns=['abs_pct_change'], inplace=True)

# %%
pfe.head()
# Out:
#             close_price    volume       date  pct_px_change  abs_pct_change
# 2012-01-10    14.571357  27730000 2012-01-10            NaN             NaN
# 2012-01-11    14.544791  28764200 2012-01-11      -0.182315        0.182315
# 2012-01-12    14.604564  27358300 2012-01-12       0.410959        0.410959
# 2012-01-13    14.504942  29067200 2012-01-13      -0.682128        0.682128
# 2012-01-17    14.568036  35544000 2012-01-17       0.434982        0.434982

# %%
# write loop to create new variable to record price changes over 5 days and store info in new dataframe
pct_px_change_5d = []
abs_pct_px_change_5d = []
date = []
x = len(pfe) - 5

for i in range(0, x):
    d = pfe['date'][i]
    px = (pfe['close_price'][i+5] - pfe['close_price'][i]) / pfe['close_price'][i] * 100
    date.append(d)
    pct_px_change_5d.append(px)
    abs_pct_px_change_5d.append(abs(px))
        
df2 = pd.DataFrame({'date':date, '5d_change':pct_px_change_5d, '5d_abs':abs_pct_px_change_5d})

# merge both dataframes
merged_df = pfe.merge(df2, on="date")

# %%
# write loop to create new variable to record price changes over 5 days and store info in new dataframe
pct_px_change_5d = []
date = []
x = len(sp500) - 5

for i in range(0, x):
    d = sp500['date'][i]
    px = (sp500['close_price'][i+5] - sp500['close_price'][i]) / sp500['close_price'][i] * 100
    date.append(d)
    pct_px_change_5d.append(px)
        
df2 = pd.DataFrame({'date':date, 'sp500_5d_change':pct_px_change_5d})

# further merge dataframes
df2 = df2.merge(sp500, on='date')
df2.drop(columns=['close_price', 'volume'], inplace=True)
df2.rename(columns={"pct_px_change": "sp500_pct_px_change"}, inplace=True)
merged_df = merged_df.merge(df2, on="date")

# %%
merged_df["adjusted"] = merged_df['pct_px_change'] - merged_df['sp500_pct_px_change']
merged_df["adjusted_abs"] = abs(merged_df["adjusted"])
merged_df["adjusted_5d"] = merged_df['5d_change'] - merged_df['sp500_5d_change']
merged_df["adjusted_5d_abs"] = abs(merged_df["adjusted_5d"])

# %%
merged_df.head()
# Out:
#    close_price    volume       date  pct_px_change  abs_pct_change  5d_change  \
# 0    14.571357  27730000 2012-01-10            NaN             NaN   0.136737
# 1    14.544791  28764200 2012-01-11      -0.182315        0.182315  -0.273973
# 2    14.604564  27358300 2012-01-12       0.410959        0.410959  -0.409277
# 3    14.504942  29067200 2012-01-13      -0.682128        0.682128  -0.595238
# 4    14.568036  35544000 2012-01-17       0.434982        0.434982  -1.253704
#
#      5d_abs  sp500_5d_change  sp500_pct_px_change  adjusted  adjusted_abs  \
# 0  0.136737         1.270038                  NaN       NaN           NaN
# 1  0.273973         1.749226             0.054209 -0.236524      0.236524
# 2  0.409277         1.884024             0.239938  0.171021      0.171021
# 3  0.595238         2.149953            -0.517335 -0.164794      0.164794
# 4  1.253704         1.639091             0.388078  0.046903      0.046903
#
#    adjusted_5d  adjusted_5d_abs
# 0    -1.133301         1.133301
# 1    -2.023199         2.023199
# 2    -2.293301         2.293301
# 3    -2.745192         2.745192
# 4    -2.892795         2.892795

# %%
# create date column so that the news data can be merged with the stock ticker data
agg_df['date'] = pd.to_datetime(agg_df.index,format="%Y-%m-%d")

# %%
# merge news & stocks data
pfizer = merged_df.merge(agg_df, on="date")
pfizer.drop(columns=['close_price', 'sp500_5d_change', 'sp500_pct_px_change'], inplace=True)

# %%
pfizer = pfizer.dropna()

# %%
pfizer.head()
# Out:
#       volume       date  pct_px_change  abs_pct_change  5d_change    5d_abs  \
# 0   29067200 2012-01-13      -0.682128        0.682128  -0.595238  0.595238
# 1  132872800 2012-01-27      -0.693481        0.693481  -0.284616  0.284616
# 2   55526800 2012-01-31      -0.834106        0.834106  -0.620020  0.620020
# 3   37375900 2012-02-07       0.477327        0.477327   1.330166  1.330166
# 4   25262900 2012-02-14       0.140845        0.140845   0.140647  0.140647
#
#    adjusted  adjusted_abs  adjusted_5d  adjusted_5d_abs  \
# 0 -0.164794      0.164794    -2.745192         2.745192
# 1 -0.647985      0.647985    -2.348036         2.348036
# 2 -0.796045      0.796045    -3.262420         3.262420
# 3  0.224445      0.224445     1.033408         1.033408
# 4  0.266436      0.266436    -0.480701         0.480701
#
#                                                                                                   text  \
# 0  [Nestle declines comment on Pfizer unit bid report ['Nestle, the world’s biggest food group, dec...
# 1  [US FDA approves Pfizer\'s Inlyta for kidney cancer ['Pfizer’s Inlyta drug for patients with adv...
# 2  [Generics take toll on Pfizer, Lilly profits ['Competition from low-cost generic drugs squeezed ...
# 3  [India\'s Pfizer to spin-off animal healthcare business ['India’s Pfizer Ltd. said its board has...
# 4  [Pfizer says its drug is best hope for Alzheimer\'s ['Pfizer Inc research chief Mikael Dolsten s...
#
#    news_count
# 0           1
# 1           1
# 2           2
# 3           3
# 4           2

# %% [markdown]
# ### Repeat the same steps for the other companies' data

# %%
def clean_updates(text):
    text = re.sub(r'UPDATE 1-', '', text)
    text = re.sub(r'UPDATE 2-', '', text)
    text = re.sub(r'UPDATE 3-', '', text)
    text = re.sub(r'UPDATE 4-', '', text)
    text = re.sub(r'BRIEF-', '', text)
    return text

# %%
def clean_and_merge(news, company, ticker):
    
    news['headlines'] = news['headlines'].apply(clean_updates)
    news.drop_duplicates(subset=['headlines'], ignore_index=True, inplace=True)
    news.drop(columns=['links'], inplace=True)
    news['article_content'] = news['article_content'].apply(remove_artcicle_tags)
    news ['news_text'] = news ['headlines'] + " " + news ['article_content'].astype(str)
    news['mentioned'] = news['news_text'].apply(lambda x: company_in_text(x, company))
    news = news[news['mentioned']==1]
    news_volume = news.groupby('dates').size()
    agg_text = news.groupby('dates')['news_text'].apply(list)
    agg_df = pd.DataFrame({'text':agg_text, 'news_count':news_volume})
    agg_df['date'] = pd.to_datetime(agg_df.index,format="%Y-%m-%d")
    
    df = scrape_stocks(ticker)
    pct_px_change_5d = []
    abs_pct_px_change_5d = []
    date = []
    x = len(df) - 5
    
    for i in range(0, x):
        d = df['date'][i]
        px = (df['close_price'][i+5] - df['close_price'][i]) / df['close_price'][i] * 100
        date.append(d)
        pct_px_change_5d.append(px)
        abs_pct_px_change_5d.append(abs(px))
        
    df2 = pd.DataFrame({'date':date, '5d_change':pct_px_change_5d, '5d_abs':abs_pct_px_change_5d})
    
    merged_df = df.merge(df2, on="date")
    data = merged_df.merge(agg_df, on="date")
    
    sp500 = scrape_stocks('spy')
    sp500.drop(columns=['abs_pct_change'], inplace=True)
    y = len(sp500) - 5
    pct_px_change_5d = []
    date = []
    
    for i in range(0, y):
        d = sp500['date'][i]
        px = (sp500['close_price'][i+5] - sp500['close_price'][i]) / sp500['close_price'][i] * 100
        date.append(d)
        pct_px_change_5d.append(px)
        
    df2 = pd.DataFrame({'date':date, 'sp500_5d_change':pct_px_change_5d})
    
    df2 = df2.merge(sp500, on='date')
    df2.drop(columns=['close_price', 'volume'], inplace=True)
    df2.rename(columns={"pct_px_change": "sp500_pct_px_change"}, inplace=True)
    merged_df = merged_df.merge(df2, on="date")
    
    merged_df["adjusted"] = merged_df['pct_px_change'] - merged_df['sp500_pct_px_change']
    merged_df["adjusted_abs"] = abs(merged_df["adjusted"])
    merged_df["adjusted_5d"] = merged_df['5d_change'] - merged_df['sp500_5d_change']
    merged_df["adjusted_5d_abs"] = abs(merged_df["adjusted_5d"])
    
    data = merged_df.merge(agg_df, on="date")
    data.drop(columns=['close_price', 'sp500_5d_change', 'sp500_pct_px_change'], inplace=True)
    
    return data

# %% [markdown]
# ### Biogen [NASDAQ: BIIB]

# %%
df = pd.read_csv("../assets/scraped_news_biogen.csv")

# %%
biogen = clean_and_merge(df, "biogen", "biib")

# %%
biogen.head()
# Out:
#     volume       date  pct_px_change  abs_pct_change  5d_change    5d_abs  \
# 0  1404800 2012-01-13      -0.232158        0.232158   0.241317  0.241317
# 1  3396400 2012-01-20       1.164583        1.164583   0.355510  0.355510
# 2  1551600 2012-01-27       0.602461        0.602461   2.800270  2.800270
# 3  2615600 2012-01-31       1.175159        1.175159   3.060619  3.060619
# 4  1029400 2012-02-14      -0.250000        0.250000  -2.664996  2.664996
#
#    adjusted  adjusted_abs  adjusted_5d  adjusted_5d_abs  \
# 0  0.285176      0.285176    -1.908637         1.908637
# 1  0.791846      0.791846     0.454033         0.454033
# 2  0.647957      0.647957     0.736850         0.736850
# 3  1.213219      1.213219     0.418219         0.418219
# 4 -0.124409      0.124409    -3.286344         3.286344
#
#                                                                                                   text  \
# 0  [Cancer drug gets stronger label warning ['Seattle Genetics Inc said it found a second instance ...
# 1  [Falcone eyes mobile asset sales, Icahn invests ['Hedge fund manager Philip Falcone is looking a...
# 2  [Oshkosh, Icahn to square off at director vote ['Oshkosh Corp OSK.N and activist investor Carl I...
# 3  [Biogen 4th quarter profit up; 2012 forecast falls short ["Biogen Idec BIIB.O is spending heavil...
# 4  [Biogen to acquire developer of fibrosis treatments ['Biogen Idec Inc BIIB.O has agreed to acqui...
#
#    news_count
# 0           1
# 1           3
# 2           1
# 3           2
# 4           1

# %% [markdown]
# ### Amgen [NASDAQ: AMGN]

# %%
df = pd.read_csv("../assets/scraped_news_amgen.csv")

# %%
amgen = clean_and_merge(df, "amgen", "amgn")

# %%
amgen.head()
# Out:
#     volume       date  pct_px_change  abs_pct_change  5d_change    5d_abs  \
# 0  6150500 2012-01-10            NaN             NaN   5.405817  5.405817
# 1  5996400 2012-01-13       0.088836        0.088836   0.266272  0.266272
# 2  5700100 2012-01-19      -0.115574        0.115574  -1.533121  1.533121
# 3  6839100 2012-01-20       0.621927        0.621927  -1.768003  1.768003
# 4  6436400 2012-01-25       1.495821        1.495821   0.910273  0.910273
#
#    adjusted  adjusted_abs  adjusted_5d  adjusted_5d_abs  \
# 0       NaN           NaN     4.135779         4.135779
# 1  0.606171      0.606171    -1.883681         1.883681
# 2 -0.643217      0.643217    -1.852610         1.852610
# 3  0.249190      0.249190    -1.669481         1.669481
# 4  0.659064      0.659064     0.978167         0.978167
#
#                                                                                                   text  \
# 0  [New DNA reader to bring promise ["A new DNA reader could bring genetics to medical clinics.Afte...
# 1  [Analysis: Investors likely to wait out 2012 drug launches ['Burned by disappointing early sales...
# 2  [Swiss stocks - Factors to watch on Jan 19 ['Swiss shares were poised to open higher on Thursday...
# 3  [EU agency issues guideline on biosimilar MS drugs ['European regulators took another step towar...
# 4  [Roche in $5.7 billion bid for gene decoder Illumina ['Swiss drugmaker Roche Holding AG ROG.VX h...
#
#    news_count
# 0           2
# 1           1
# 2           1
# 3           1
# 4           1

# %% [markdown]
# ### AbbVie [NYSE: ABBV]

# %%
df = pd.read_csv("../assets/scraped_news_abbvie.csv")

# %%
abbvie = clean_and_merge(df, "abbvie", "abbv")

# %%
abbvie.head()
# Out:
#      volume       date  pct_px_change  abs_pct_change  5d_change    5d_abs  \
# 0  18800400 2013-01-09       0.563631        0.563631   6.076609  6.076609
# 1  13040200 2013-01-15       1.496040        1.496040   9.248555  9.248555
# 2  10981600 2013-01-23       3.789127        3.789127  -2.301587  2.301587
# 3  10841800 2013-01-30      -1.018494        1.018494   0.568643  0.568643
# 4   7284400 2013-02-05      -0.214592        0.214592  -4.784946  4.784946
#
#    adjusted  adjusted_abs  adjusted_5d  adjusted_5d_abs  \
# 0  0.309423      0.309423     5.302212         5.302212
# 1  1.427999      1.427999     7.684674         7.684674
# 2  3.628193      3.628193    -2.770222         2.770222
# 3 -0.626883      0.626883    -0.157684         0.157684
# 4 -1.224356      1.224356    -5.427118         5.427118
#
#                                                                                                   text  \
# 0  [AbbVie sees no need for major acquisitions-CFO ['AbbVie Inc, the pharmaceutical company spun of...
# 1  [Analysis: Drug industry bets on new blockbusters in 2013 ['Drugmakers are betting that a new wa...
# 2  [Abbott results bode well for spun-off AbbVie ['AbbVie Inc, the new branded pharmaceuticals comp...
# 3  [AbbVie forecasts slower Humira growth ['AbbVie ABBV.N, the pharmaceuticals business spun off ea...
# 4  [Senate to mull ban on \\"pay for delay\\" pharmaceutical deals ['Key Democratic and Republican ...
#
#    news_count
# 0           1
# 1           1
# 2           1
# 3           4
# 4           2

# %% [markdown]
# ### Gilead [NASDAQ: GILD]

# %%
df = pd.read_csv("../assets/scraped_news_gilead.csv")

# %%
gilead = clean_and_merge(df, "gilead", "gild")

# %%
gilead.head()
# Out:
#      volume       date  pct_px_change  abs_pct_change  5d_change     5d_abs  \
# 0  15055000 2012-01-10            NaN             NaN   7.367232   7.367232
# 1   7038000 2012-01-20       0.487185        0.487185   2.698145   2.698145
# 2  37671600 2012-02-03      10.920706       10.920706  -1.727763   1.727763
# 3   7321500 2012-02-14      -0.628415        0.628415 -18.375951  18.375951
# 4   6095400 2012-02-15       0.485748        0.485748 -17.639548  17.639548
#
#    adjusted  adjusted_abs  adjusted_5d  adjusted_5d_abs  \
# 0       NaN           NaN     6.097194         6.097194
# 1  0.114448      0.114448     2.796667         2.796667
# 2  9.518837      9.518837    -1.593974         1.593974
# 3 -0.502824      0.502824   -18.997299        18.997299
# 4  0.951759      0.951759   -19.177895        19.177895
#
#                                                                                                   text  \
# 0  [Pharma pays up for scarce assets ['When it comes to healthcare deals, the new motto may be “too...
# 1  [FDA lifts hold on Insmed\'s lung disease drug ["Insmed Inc INSM.O said U.S. health regulators l...
# 2  [Nasdaq vaults to 11-year high on surge in jobs ["A surge in hiring in the world’s largest econo...
# 3  [Duquesne alumni reveal holdings at Point State ["Point State Capital, one of last year's most c...
# 4  [TV network aims for new viewing audience: dogs ['Nielsen isn’t tracking the network’s ratings a...
#
#    news_count
# 0           1
# 1           1
# 2           1
# 3           2
# 4           1

# %% [markdown]
# ### Merck [NYSE: MRK]

# %%
df = pd.read_csv("../assets/scraped_news_merck.csv")

# %%
merck = clean_and_merge(df, "merck", "mrk")

# %%
merck.head()
# Out:
#      volume       date  pct_px_change  abs_pct_change  5d_change    5d_abs  \
# 0  11366200 2012-01-10            NaN             NaN   0.908619  0.908619
# 1  11945800 2012-01-11      -0.285566        0.285566   2.212965  2.212965
# 2   9677400 2012-01-13      -0.751101        0.751101   1.174322  1.174322
# 3  16546800 2012-01-19       1.003344        1.003344  -1.222618  1.222618
# 4  15333900 2012-01-20      -0.152827        0.152827  -1.734694  1.734694
#
#    adjusted  adjusted_abs  adjusted_5d  adjusted_5d_abs  \
# 0       NaN           NaN    -0.361419         0.361419
# 1 -0.339775      0.339775     0.463739         0.463739
# 2 -0.233766      0.233766    -0.975632         0.975632
# 3  0.475701      0.475701    -1.542107         1.542107
# 4 -0.525564      0.525564    -1.636172         1.636172
#
#                                                                                                   text  \
# 0  [FDA says Merck\'s HIV drug gets generic threat ['Health regulators said they have received appl...
# 1  [German stocks - Factors to watch on January 11 ['The following are some of the factors that may...
# 2  [China seeks to unlock secrets of herbs, roots ["Chinese legends have long extolled the benefits...
# 3  [Merck resolves Vioxx litigation in Canada ['Merck & Co MRK.N on Thursday said it had reached a ...
# 4  [Achillion shares fall on concerns over hep C drug\'s future ["Achillion Pharmaceuticals' ACHN.O...
#
#    news_count
# 0           2
# 1           2
# 2           2
# 3           1
# 4           2

# %% [markdown]
# ### Eli Lilly [NYSE: LLY]

# %%
df = pd.read_csv("../assets/scraped_news_lilly.csv")

# %%
lilly = clean_and_merge(df, "lilly", "lly")

# %%
lilly.head()
# Out:
#     volume       date  pct_px_change  abs_pct_change  5d_change    5d_abs  \
# 0  5085900 2012-01-11      -0.867840        0.867840   0.475238  0.475238
# 1  4420100 2012-01-13      -0.597312        0.597312  -1.352028  1.352028
# 2  5899600 2012-01-17       0.225338        0.225338  -1.049213  1.049213
# 3  5173700 2012-01-18       0.374719        0.374719  -0.721752  0.721752
# 4  9629000 2012-01-23      -1.029892        1.029892  -0.380711  0.380711
#
#    adjusted  adjusted_abs  adjusted_5d  adjusted_5d_abs  \
# 0 -0.922049      0.922049    -1.273988         1.273988
# 1 -0.079978      0.079978    -3.501981         3.501981
# 2 -0.162740      0.162740    -2.688304         2.688304
# 3 -0.730894      0.730894    -2.090568         2.090568
# 4 -0.772219      0.772219    -0.198354         0.198354
#
#                                                                                                   text  \
# 0  [Antibiotics for livestock vital to feed world -OIE ['The world body in charge of fighting anima...
# 1  [Analysis: Investors likely to wait out 2012 drug launches ['Burned by disappointing early sales...
# 2  [China vaccine maker joins Aeras in fight against TB ['China’s top vaccine maker is teaming up w...
# 3  [How to play it: Finding value in healthcare ['It’s the sector that can’t seem to catch a break....
# 4  [FDA extends review of Alexza product, shares fall ['Alexza Pharmaceuticals Inc said U.S. health...
#
#    news_count
# 0           3
# 1           1
# 2           1
# 3           1
# 4           1

# %% [markdown]
# ### Regeneron Pharmaceuticals [NASDAQ: REGN]

# %%
df = pd.read_csv("../assets/scraped_news_regeneron.csv")

# %%
regeneron = clean_and_merge(df, "regeneron", "regn")

# %%
regeneron.head()
# Out:
#     volume       date  pct_px_change  abs_pct_change  5d_change     5d_abs  \
# 0  2335500 2012-01-12       1.163392        1.163392   0.089445   0.089445
# 1  1818000 2012-01-13       0.843343        0.843343  -0.468829   0.468829
# 2  1136000 2012-01-27       4.508247        4.508247  13.233575  13.233575
# 3  4161600 2012-02-13      12.313871       12.313871 -13.423463  13.423463
# 4   338300 2012-03-09       0.951036        0.951036   7.573920   7.573920
#
#     adjusted  adjusted_abs  adjusted_5d  adjusted_5d_abs  \
# 0   0.923454      0.923454    -1.794579         1.794579
# 1   1.360677      1.360677    -2.618783         2.618783
# 2   4.553743      4.553743    11.170155        11.170155
# 3  11.569602     11.569602   -14.243498        14.243498
# 4   0.564287      0.564287     5.143238         5.143238
#
#                                                                                                   text  \
# 0  [CORRECTED-Regeneron posts \'11 Eylea sales of $24-25 mln ['Sales of Eylea, the eye drug launche...
# 1  [Analysis: Investors likely to wait out 2012 drug launches ['Burned by disappointing early sales...
# 2  [Infinity stops cancer drug trial ['Infinity Pharmaceuticals pulled the plug on a mid-stage tria...
# 3  [US STOCKS-Wall St higher on Greek deal, banks lead ['U.S. stocks rose Monday as Greece’s parlia...
# 4  [FDA asks experts if pain drugs get second chance ['U.S. drug regulators are asking experts for ...
#
#    news_count
# 0           1
# 1           1
# 2           1
# 3           7
# 4           1

# %% [markdown]
# ### Merge dataframes

# %%
merged = pd.concat([pfizer, biogen, amgen, abbvie, gilead, lilly, merck, regeneron])

# %%
merged.head()
# Out:
#       volume       date  pct_px_change  abs_pct_change  5d_change    5d_abs  \
# 0   29067200 2012-01-13      -0.682128        0.682128  -0.595238  0.595238
# 1  132872800 2012-01-27      -0.693481        0.693481  -0.284616  0.284616
# 2   55526800 2012-01-31      -0.834106        0.834106  -0.620020  0.620020
# 3   37375900 2012-02-07       0.477327        0.477327   1.330166  1.330166
# 4   25262900 2012-02-14       0.140845        0.140845   0.140647  0.140647
#
#    adjusted  adjusted_abs  adjusted_5d  adjusted_5d_abs  \
# 0 -0.164794      0.164794    -2.745192         2.745192
# 1 -0.647985      0.647985    -2.348036         2.348036
# 2 -0.796045      0.796045    -3.262420         3.262420
# 3  0.224445      0.224445     1.033408         1.033408
# 4  0.266436      0.266436    -0.480701         0.480701
#
#                                                                                                   text  \
# 0  [Nestle declines comment on Pfizer unit bid report ['Nestle, the world’s biggest food group, dec...
# 1  [US FDA approves Pfizer\'s Inlyta for kidney cancer ['Pfizer’s Inlyta drug for patients with adv...
# 2  [Generics take toll on Pfizer, Lilly profits ['Competition from low-cost generic drugs squeezed ...
# 3  [India\'s Pfizer to spin-off animal healthcare business ['India’s Pfizer Ltd. said its board has...
# 4  [Pfizer says its drug is best hope for Alzheimer\'s ['Pfizer Inc research chief Mikael Dolsten s...
#
#    news_count
# 0           1
# 1           1
# 2           2
# 3           3
# 4           2

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7252 entries, 0 to 559
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   volume           7252 non-null   int64
#  1   date             7252 non-null   datetime64[ns]
#  2   pct_px_change    7249 non-null   float64
#  3   abs_pct_change   7249 non-null   float64
#  4   5d_change        7252 non-null   float64
#  5   5d_abs           7252 non-null   float64
#  6   adjusted         7249 non-null   float64
#  7   adjusted_abs     7249 non-null   float64
#  8   adjusted_5d      7252 non-null   float64
#  9   adjusted_5d_abs  7252 non-null   float64
#  10  text             7252 non-null   object
#  11  news_count       7252 non-null   int64
# dtypes: datetime64[ns](1), float64(8), int64(2), object(1)
# memory usage: 736.5+ KB

# %%
# export merged dataset to csv 
merged.to_csv("../assets/merged.csv", index=False)
